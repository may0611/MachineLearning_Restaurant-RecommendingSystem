# %%
import pandas as pd

# %%
review = pd.read_csv('/content/drive/MyDrive/yelp_academic_dataset_review.csv')
# Out:
# <ipython-input-2-7b3fd085d34a>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   review = pd.read_csv('/content/drive/MyDrive/yelp_academic_dataset_review.csv')

# %%
review.head()
# Out:
#   Unnamed: 0               review_id                 user_id  \
# 0          0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1          1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2          2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3          3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4          4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
#
#               business_id  stars  useful  funny  cool  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    3.0     0.0    0.0   0.0
# 1  7ATYjTIgM3jUlt4UM3IypQ    5.0     1.0    0.0   1.0
# 2  YjUWPpI6HXG530lwP-fb2A    3.0     0.0    0.0   0.0
# 3  kxX2SOes4o-D3ZQBkiMRfA    5.0     1.0    0.0   1.0
# 4  e4Vwtrqf-wpJfwesgvdgxQ    4.0     1.0    0.0   1.0
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# ...

# %%
merged_data = pd.read_csv('/content/merged_data2.csv')

# %%
merged_data.head()
# Out:
#    Unnamed: 0                 user_id             business_id  stars  name
# 0           0  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ    4.0  Melt
# 1           1  aG7fzKXqZuG-0vW6NFt8zA  e4Vwtrqf-wpJfwesgvdgxQ    5.0  Melt
# 2           2  mUIww29FcFs5E67eZsMdvw  e4Vwtrqf-wpJfwesgvdgxQ    5.0  Melt
# 3           3  uzHh5QORBRg8PkO4yg4rIg  e4Vwtrqf-wpJfwesgvdgxQ    5.0  Melt
# 4           4  3bRv6h4oOu1lk7N0EEi4DA  e4Vwtrqf-wpJfwesgvdgxQ    5.0  Melt

# %%
user_id = merged_data['user_id'].tolist()

# %%
len(user_id)
# Out:
# 2085512

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2085512 entries, 0 to 2085511
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Unnamed: 0   int64
#  1   user_id      object
#  2   business_id  object
#  3   stars        float64
#  4   name         object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 79.6+ MB

# %%
user_id = list(set(user_id))

# %%
df = review[review['user_id'].isin(user_id)]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'review_id', 'user_id', 'business_id', 'stars', 'useful',
#        'funny', 'cool', 'text', 'date'],
#       dtype='object')

# %%
df1 = df[['review_id','user_id','business_id','stars','text']]

# %%
df1.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars                                               text
# 0    3.0  If you decide to eat here, just be aware it is...
# 1    5.0  I've taken a lot of spin classes over the year...
# 2    3.0  Family diner. Had the buffet. Eclectic assortm...
# 3    5.0  Wow!  Yummy, different,  delicious.   Our favo...
# 4    4.0  Cute interior and owner (?) gave us tour of up...

# %%
df1 = df1.sample(n=100000, random_state=42)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()


def extract_and_normalize_words(text):

    text = text.lower()

    text = re.sub(r'[^a-z\s]', '', text)

    words = word_tokenize(text)

    meaningful_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(meaningful_words)


df1['text'] = df1['text'].apply(extract_and_normalize_words)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def normalize_and_split(text):
    text = re.sub(r'[^a-z\s]', '', text.lower())
    words = text.split()
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return lemmatized_words


df1['text'] = df1['text'].apply(normalize_and_split)

# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer


nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()


def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)


def lemmatize_word_list(word_list):

    lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in word_list]
    return lemmatized_words


df1['text'] = df1['text'].apply(lemmatize_word_list)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df1.head()
# Out:
#                       review_id                 user_id  \
# 4935033  EuDpnA_CWzUP58f7HrVMZQ  BtVFfQuN2u4mFaz5MDC6LQ
# 5009776  QDbJ6KkRZqdbajNeV5brLQ  tqxa573ccwIAZW61LG_-AA
# 1508982  2x9Ic6XdD3SWOATqhcdCOQ  FXvnTlk9Kf5unS_2tYw-5Q
# 800485   wpNr1hOpFIBOARA4zY58oA  vTlEeHv3oGvRerFSQsj7mw
# 4505882  LzK8ndRyETxYrykY_FaK2g  XHlXmsQJbh0yI8lEsoBg2w
#
#                     business_id  stars  \
# 4935033  SjiRaZoWaDpkCCpq5SsrMw    5.0
# 5009776  tkehxQ-wmJk7xZ_op1r1nQ    5.0
# 1508982  9n1Iv4X5S6SAPzDbkpfutA    1.0
# 800485   -gJ3m24voBGR-8fS_hQN9A    3.0
# 4505882  i_FWONQD1ZBqrNE2b-M5Ug    5.0
#
#                                                       text
# 4935033  [husband, stop, quick, bite, eat, leave, airpo...
# 5009776  [friendly, staff, great, buffet, boyfriend, fr...
# 1508982  [parent, favorite, place, go, come, year, even...
# 800485   [nicely, decorate, attentive, wait, staff, tak...
# 4505882  [good, come, back, next, morning, brunch, cant...

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  EuDpnA_CWzUP58f7HrVMZQ  BtVFfQuN2u4mFaz5MDC6LQ  SjiRaZoWaDpkCCpq5SsrMw
# 1  QDbJ6KkRZqdbajNeV5brLQ  tqxa573ccwIAZW61LG_-AA  tkehxQ-wmJk7xZ_op1r1nQ
# 2  2x9Ic6XdD3SWOATqhcdCOQ  FXvnTlk9Kf5unS_2tYw-5Q  9n1Iv4X5S6SAPzDbkpfutA
# 3  wpNr1hOpFIBOARA4zY58oA  vTlEeHv3oGvRerFSQsj7mw  -gJ3m24voBGR-8fS_hQN9A
# 4  LzK8ndRyETxYrykY_FaK2g  XHlXmsQJbh0yI8lEsoBg2w  i_FWONQD1ZBqrNE2b-M5Ug
#
#    stars                                               text
# 0    5.0                      quick bite nice soft crawfish
# 1    5.0                    friendly great frequent unhappy
# 2    1.0                          favorite wanted dont give
# 3    3.0  attentive wait anniversary read love request d...
# 4    5.0    good next enough enjoyable phenomenal enjoyable

# %%
value = df1.loc[0, 'text']
len(value)
# Out:
# 29

# %%
df1['text'] = df1['text'].str.split()

# %%
df1.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  EuDpnA_CWzUP58f7HrVMZQ  BtVFfQuN2u4mFaz5MDC6LQ  SjiRaZoWaDpkCCpq5SsrMw
# 1  QDbJ6KkRZqdbajNeV5brLQ  tqxa573ccwIAZW61LG_-AA  tkehxQ-wmJk7xZ_op1r1nQ
# 2  2x9Ic6XdD3SWOATqhcdCOQ  FXvnTlk9Kf5unS_2tYw-5Q  9n1Iv4X5S6SAPzDbkpfutA
# 3  wpNr1hOpFIBOARA4zY58oA  vTlEeHv3oGvRerFSQsj7mw  -gJ3m24voBGR-8fS_hQN9A
# 4  LzK8ndRyETxYrykY_FaK2g  XHlXmsQJbh0yI8lEsoBg2w  i_FWONQD1ZBqrNE2b-M5Ug
#
#    stars                                               text
# 0    5.0                [quick, bite, nice, soft, crawfish]
# 1    5.0               [friendly, great, frequent, unhappy]
# 2    1.0                     [favorite, wanted, dont, give]
# 3    3.0  [attentive, wait, anniversary, read, love, req...
# 4    5.0  [good, next, enough, enjoyable, phenomenal, en...

# %%
df1.to_csv('pos_tag',index = False)
